# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('out/jl-syn__000009__.dat')

# %%
x = np.reshape(data[:,0],(200,200))
y = np.reshape(data[:,1],(200,200))
z = np.reshape(data[:,2],(200,200))

# %%
plt.contourf(x,y,z,100)
